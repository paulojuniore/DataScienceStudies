# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x * x

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# Funcional
plt.plot(x, y, 'r--')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r*-')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g--')

# %%
# Orientada a objetos
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y)
axes2.plot(y, x)

axes1.set_xlabel('Eixo X')
axes1.set_ylabel('Eixo Y')
axes1.set_title('Título do Gráfico')
axes2.set_title('Título do Gráfico 2')
# Out:
# Text(0.5, 1.0, 'Título do Gráfico 2')

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, 'b--')
ax.plot(x, x**4, 'm-.')
ax.set_xlabel('Eixo X')
ax.set_ylabel('Eixo Y')
ax.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# %%
for axe in ax:
    axe.plot(x, y, 'b')
    axe.set_title('Título do gráfico')

# %%
fig

# %%
fig, ax = plt.subplots(nrows=5, ncols=5)
plt.tight_layout()

# %%
fig, axes = plt.subplots(figsize=(5, 5))
axes.plot(x, y, 'r--', label='x ** 2')
axes.plot(y, x, 'b--', label='x ** 1/2')
axes.set_title('Parábola')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.legend()

# %%
fig.savefig('image.png')
